# %%
import matplotlib.pyplot as plt
import matplotlib.animation
import time
import random
# %matplotlib notebook

xdata = []
ydata = []

axes = plt.gca()
line, = axes.plot(xdata, ydata, 'r-')

counter=0
class Node:
    def __init__(self,val):
        self.val=val

def generateObj():
    a=0
    while True:
        a+=1
        yield Node(a)

def update(i):
    global counter
    counter+=1
    xdata.append(counter)
    ydata.append(i.val)
    line.set_xdata(xdata)
    line.set_ydata(ydata)
    axes.set_xlim(0, counter)
    axes.set_ylim(0, 100)

ani= matplotlib.animation.FuncAnimation(plt.gcf(), update, frames=generateObj(),
                                       interval=100, repeat=False)

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
import update_test_data as utd
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.animation
import time
import random
# %matplotlib notebook

start_time = dt.datetime.now()
first_sample_end = None
num_samples = 0

xdata = []
ydata = []

axes = plt.gca()
line, = axes.plot(xdata, ydata, 'r-')

def generate_frame():
    a=0
    while True:
        a+=1
        yield a
        
def update(i):
    global num_samples
    end_time, left_accel, _, _ = utd.get_new_batch(start_time)
    
ani= matplotlib.animation.FuncAnimation(plt.gcf(), update, frames=generate_frame(),
                                       interval=4000, repeat=False)

plt.show()
